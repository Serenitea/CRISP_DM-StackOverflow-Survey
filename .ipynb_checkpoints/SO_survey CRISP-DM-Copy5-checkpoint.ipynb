# %%
# import libraries here; add more as necessary
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# global printing options
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %% [markdown]
# Questions explored:
# 1. Which are the current most commonly used programming languages?
# 2. How has the prevalance of different programming languages changed throughout the past **five????** years?
# 3. Which programming languages are the currently the most popular for specific types of developers?
#
# Poss questions:
#
# - mode of education + diff lang/frameworks/plats?
# - years of experience + diff lang/frameworks/plats?

# %% [markdown]
# Challenges:
#
# As is often the case with the practicalities of real-life data, the Stack Overflow developer survey varies each year, presenting unique challenges to making cross-year comparisons.
#
# 1. The same languages are classified differently from year-to-year. For instance, HTML and CSS are combined under one category in the 2019 survey, categorized separately in the 2018 survey, and nonexistent in 2017 and prior surveys.
# 2. The question in 2017 covers "technologies that you work with", including languages, databases, platforms, and frameworks. The 2018 and 2019 surveys thankfully separated these different variables, but that still means more cleaning for the 2017 dataset!
# 3. The addition of an "Others" category in 2019 that replaces the most obscure entries from earlier years. For consistency across years, I opted to combine the obscure languages from before 2019 into a single category "Other(s)".
#
#
# Problem variables:
#
# - HTML/CSS for 2019, 2018 has HTML and CSS separately.
# - Bash/Shell/PowerShell for 2019, 2018 has Bash/Shell
# - 2019 has an "Other" category

# %% [markdown]
# End goal - create a line graph of prevalence of languages across different years
#
# - [ ] clean names of 2015 data
# - [ ] merge all visual basic under 'Visual Basic / VBA'
# - [ ] all years have "Other(s)" as a category
# - [ ] delete HTML/CSS from 2018+19
# - [ ] delete non-language categories from 2017 and prior
# - [ ] uniform Shell/Powershell category
# - [ ] chart with languages and years

# %% [markdown]
# 2019: LanguageWorkedWith
#
# 2018: LanguageWorkedWith
#
# 2017: HaveWorkedLanguage
#
# 2016: tech_do

# %%
df2019 = pd.read_csv('./2019survey_results_public.csv', header = 0, skipinitialspace= True)
df2018 = pd.read_csv('./2018survey_results_public.csv', header = 0, skipinitialspace= True)
df2017 = pd.read_csv('./2017survey_results_public.csv', header = 0, skipinitialspace= True)
df2016 = pd.read_csv('./2016survey_results.csv', header = 0, skipinitialspace= True)
df2015 = pd.read_csv('./2015survey_results.csv', header = 1, skipinitialspace= True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (5,108,121,196,197,198) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
display(df2019.head(), df2018.head(), df2017.head(), df2016.head(), df2015.head())
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# 2                      Employed full-time                Thailand
# 3                      Employed full-time           United States
# 4                      Employed full-time                 Ukraine
#
#           Student                                            EdLevel  \
# 0              No                          Primary/elementary school
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
# 2              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 3              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                       UndergradMajor  \
# 0                                                NaN
# 1                                                NaN
# 2                      Web development or web design
# 3  Computer science, computer engineering, or sof...
# 4  Computer science, computer engineering, or sof...
#
#                                             EduOther  \
# 0  Taught yourself a new language, framework, or ...
# 1  Taken an online course in programming or softw...
# 2  Taught yourself a new language, framework, or ...
# 3  Taken an online course in programming or softw...
# 4  Taken an online course in programming or softw...
#
#                     OrgSize  \
# 0                       NaN
# 1                       NaN
# 2      100 to 499 employees
# 3      100 to 499 employees
# 4  10,000 or more employees
#
#                                              DevType YearsCode Age1stCode  \
# 0                                                NaN         4         10
# 1  Developer, desktop or enterprise applications;...       NaN         17
# 2  Designer;Developer, back-end;Developer, front-...         3         22
# 3                              Developer, full-stack         3         16
# 4  Academic researcher;Developer, desktop or ente...        16         14
#
#        YearsCodePro           CareerSat                 JobSat  \
# 0               NaN                 NaN                    NaN
# 1               NaN                 NaN                    NaN
# 2                 1  Slightly satisfied     Slightly satisfied
# 3  Less than 1 year      Very satisfied     Slightly satisfied
# 4                 9   Very dissatisfied  Slightly dissatisfied
#
#                MgrIdiot  MgrMoney   MgrWant  \
# 0                   NaN       NaN       NaN
# 1                   NaN       NaN       NaN
# 2  Not at all confident  Not sure  Not sure
# 3        Very confident        No  Not sure
# 4    Somewhat confident       Yes        No
#
#                                              JobSeek          LastHireDate  \
# 0                                                NaN                   NaN
# 1                    I am actively looking for a job  I've never had a job
# 2  I’m not actively looking, but I am open to new...         1-2 years ago
# 3       I am not interested in new job opportunities  Less than a year ago
# 4       I am not interested in new job opportunities  Less than a year ago
#
#                                              LastInt FizzBuzz  \
# 0                                                NaN      NaN
# 1                                                NaN      NaN
# 2                Interview with people in peer roles       No
# 3  Write code by hand (e.g., on a whiteboard);Int...       No
# 4  Write any code;Write code by hand (e.g., on a ...       No
#
#                                           JobFactors  \
# 0                                                NaN
# 1  Financial performance or funding status of the...
# 2  Languages, frameworks, and other technologies ...
# 3  Languages, frameworks, and other technologies ...
# 4  Industry that I'd be working in;Languages, fra...
#
#                                         ResumeUpdate CurrencySymbol  \
# 0                                                NaN            NaN
# 1  Something else changed (education, award, medi...            NaN
# 2                   I was preparing for a job search            THB
# 3                   I was preparing for a job search            USD
# 4                   I was preparing for a job search            UAH
#
#            CurrencyDesc  CompTotal CompFreq  ConvertedComp  WorkWeekHrs  \
# 0                   NaN        NaN      NaN            NaN          NaN
# 1                   NaN        NaN      NaN            NaN          NaN
# 2             Thai baht    23000.0  Monthly         8820.0         40.0
# 3  United States dollar    61000.0   Yearly        61000.0         80.0
# 4     Ukrainian hryvnia        NaN      NaN            NaN         55.0
#
#                                             WorkPlan  \
# 0                                                NaN
# 1                                                NaN
# 2  There's no schedule or spec; I work on what se...
# 3  There's no schedule or spec; I work on what se...
# 4  There is a schedule and/or spec (made by me or...
#
#                                        WorkChallenge  \
# 0                                                NaN
# 1                                                NaN
# 2  Distracting work environment;Inadequate access...
# 3                                                NaN
# 4  Being tasked with non-development work;Inadequ...
#
#                          WorkRemote WorkLoc                  ImpSyn  \
# 0                               NaN     NaN                     NaN
# 1                               NaN     NaN                     NaN
# 2  Less than once per month / Never    Home                 Average
# 3  Less than once per month / Never    Home  A little below average
# 4             A few days each month  Office  A little above average
#
#                                    CodeRev  CodeRevHrs  \
# 0                                      NaN         NaN
# 1                                      NaN         NaN
# 2                                       No         NaN
# 3                                       No         NaN
# 4  Yes, because I see value in code review         NaN
#
#                        UnitTests  \
# 0                            NaN
# 1                            NaN
# 2      No, but I think we should
# 3      No, but I think we should
# 4  Yes, it's part of our process
#
#                                          PurchaseHow  \
# 0                                                NaN
# 1                                                NaN
# 2                                           Not sure
# 3  Developers typically have the most influence o...
# 4                                           Not sure
#
#                     PurchaseWhat                           LanguageWorkedWith  \
# 0                            NaN              HTML/CSS;Java;JavaScript;Python
# 1                            NaN                          C++;HTML/CSS;Python
# 2  I have little or no influence                                     HTML/CSS
# 3  I have little or no influence                          C;C++;C#;Python;SQL
# 4  I have little or no influence  C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#
#                             LanguageDesireNextYear  \
# 0  C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 1                      C++;HTML/CSS;JavaScript;SQL
# 2                                  Elixir;HTML/CSS
# 3                              C;C#;JavaScript;SQL
# 4         HTML/CSS;Java;JavaScript;SQL;WebAssembly
#
#                                  DatabaseWorkedWith  \
# 0                                            SQLite
# 1                                               NaN
# 2                                        PostgreSQL
# 3                                      MySQL;SQLite
# 4  Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
#
#                               DatabaseDesireNextYear  \
# 0                                              MySQL
# 1                                              MySQL
# 2                                         PostgreSQL
# 3                                       MySQL;SQLite
# 4  Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
#
#                   PlatformWorkedWith                 PlatformDesireNextYear  \
# 0                      MacOS;Windows                Android;Arduino;Windows
# 1                            Windows                                Windows
# 2                                NaN                                    NaN
# 3                      Linux;Windows                          Linux;Windows
# 4  Android;Linux;MacOS;Slack;Windows  Android;Docker;Kubernetes;Linux;Slack
#
#                             WebFrameWorkedWith        WebFrameDesireNextYear  \
# 0                                 Django;Flask                  Flask;jQuery
# 1                                       Django                        Django
# 2                                          NaN                     Other(s):
# 3                                          NaN                           NaN
# 4  Django;Express;Flask;jQuery;React.js;Spring  Flask;jQuery;React.js;Spring
#
#   MiscTechWorkedWith                    MiscTechDesireNextYear  \
# 0            Node.js                                   Node.js
# 1                NaN                                       NaN
# 2                NaN                                       NaN
# 3               .NET                                      .NET
# 4    Cordova;Node.js  Apache Spark;Hadoop;Node.js;React Native
#
#                                      DevEnviron        OpSys  \
# 0                    IntelliJ;Notepad++;PyCharm      Windows
# 1                                  Atom;PyCharm      Windows
# 2                        Vim;Visual Studio Code  Linux-based
# 3  Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 4                        IntelliJ;Notepad++;Vim  Linux-based
#
#                                Containers BlockchainOrg  \
# 0                 I do not use containers           NaN
# 1                 I do not use containers           NaN
# 2                 I do not use containers           NaN
# 3                 I do not use containers    Not at all
# 4  Outside of work, for personal projects    Not at all
#
#                                         BlockchainIs BetterLife  \
# 0                                                NaN        Yes
# 1  Useful across many domains and could change ma...        Yes
# 2                                                NaN        Yes
# 3  Useful for decentralized currency (i.e., Bitcoin)        Yes
# 4                                                NaN        Yes
#
#                                    ITperson OffOn SocialMedia  \
# 0  Fortunately, someone else has that title   Yes     Twitter
# 1                                       Yes   Yes   Instagram
# 2                                       Yes   Yes      Reddit
# 3                                      SIGH   Yes      Reddit
# 4                                  Also Yes   Yes    Facebook
#
#                Extraversion ScreenName        SOVisit1st  \
# 0                    Online   Username              2017
# 1                    Online   Username              2017
# 2  In real life (in person)   Username              2011
# 3  In real life (in person)   Username              2014
# 4  In real life (in person)   Username  I don't remember
#
#                        SOVisitFreq  \
# 0  A few times per month or weekly
# 1            Daily or almost daily
# 2             A few times per week
# 3            Daily or almost daily
# 4           Multiple times per day
#
#                                            SOVisitTo  \
# 0  Find answers to specific questions;Learn how t...
# 1  Find answers to specific questions;Learn how t...
# 2  Find answers to specific questions;Learn how t...
# 3  Find answers to specific questions;Pass the ti...
# 4                 Find answers to specific questions
#
#                   SOFindAnswer                     SOTimeSaved  SOHowMuchTime  \
# 0           3-5 times per week  Stack Overflow was much faster  31-60 minutes
# 1           3-5 times per week  Stack Overflow was much faster  11-30 minutes
# 2          6-10 times per week        They were about the same            NaN
# 3           1-2 times per week  Stack Overflow was much faster  31-60 minutes
# 4  More than 10 times per week  Stack Overflow was much faster            NaN
#
#   SOAccount                           SOPartFreq  \
# 0        No                                  NaN
# 1       Yes      A few times per month or weekly
# 2       Yes  Less than once per month or monthly
# 3       Yes  Less than once per month or monthly
# 4       Yes      A few times per month or weekly
#
#                                               SOJobs  \
# 0  No, I didn't know that Stack Overflow had a jo...
# 1  No, I knew that Stack Overflow had a job board...
# 2                                                Yes
# 3                                                Yes
# 4  No, I knew that Stack Overflow had a job board...
#
#                                             EntTeams           SOComm  \
# 0                No, and I don't know what those are          Neutral
# 1                No, and I don't know what those are    Yes, somewhat
# 2  No, I've heard of them, but I am not part of a...          Neutral
# 3                No, and I don't know what those are   No, not really
# 4  No, I've heard of them, but I am not part of a...  Yes, definitely
#
#                              WelcomeChange  \
# 0  Just as welcome now as I felt last year
# 1  Just as welcome now as I felt last year
# 2  Just as welcome now as I felt last year
# 3  Just as welcome now as I felt last year
# 4  Just as welcome now as I felt last year
#
#                                         SONewContent   Age Gender Trans  \
# 0  Tech articles written by other developers;Indu...  14.0    Man    No
# 1  Tech articles written by other developers;Indu...  19.0    Man    No
# 2  Tech meetups or events in your area;Courses on...  28.0    Man    No
# 3  Tech articles written by other developers;Indu...  22.0    Man    No
# 4  Tech meetups or events in your area;Courses on...  30.0    Man    No
#
#                  Sexuality                                 Ethnicity  \
# 0  Straight / Heterosexual                                       NaN
# 1  Straight / Heterosexual                                       NaN
# 2  Straight / Heterosexual                                       NaN
# 3  Straight / Heterosexual              White or of European descent
# 4  Straight / Heterosexual  White or of European descent;Multiracial
#
#   Dependents           SurveyLength                  SurveyEase
# 0         No  Appropriate in length  Neither easy nor difficult
# 1         No  Appropriate in length  Neither easy nor difficult
# 2        Yes  Appropriate in length  Neither easy nor difficult
# 3         No  Appropriate in length                        Easy
# 4         No  Appropriate in length                        Easy
#    Respondent Hobby OpenSource         Country         Student  \
# 0           1   Yes         No           Kenya              No
# 1           3   Yes        Yes  United Kingdom              No
# 2           4   Yes        Yes   United States              No
# 3           5    No         No   United States              No
# 4           7   Yes         No    South Africa  Yes, part-time
#
#            Employment                                    FormalEducation  \
# 0  Employed part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2  Employed full-time                                   Associate degree
# 3  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4  Employed full-time  Some college/university study without earning ...
#
#                                       UndergradMajor  \
# 0                          Mathematics or statistics
# 1  A natural science (ex. biology, chemistry, phy...
# 2  Computer science, computer engineering, or sof...
# 3  Computer science, computer engineering, or sof...
# 4  Computer science, computer engineering, or sof...
#
#                 CompanySize  \
# 0        20 to 99 employees
# 1  10,000 or more employees
# 2        20 to 99 employees
# 3      100 to 499 employees
# 4  10,000 or more employees
#
#                                              DevType       YearsCoding  \
# 0                               Full-stack developer         3-5 years
# 1  Database administrator;DevOps specialist;Full-...  30 or more years
# 2           Engineering manager;Full-stack developer       24-26 years
# 3                               Full-stack developer       18-20 years
# 4  Data or business analyst;Desktop or enterprise...         6-8 years
#
#   YearsCodingProf                     JobSatisfaction  \
# 0       3-5 years                 Extremely satisfied
# 1     18-20 years             Moderately dissatisfied
# 2       6-8 years                Moderately satisfied
# 3     12-14 years  Neither satisfied nor dissatisfied
# 4       0-2 years                  Slightly satisfied
#
#                    CareerSatisfaction  \
# 0                 Extremely satisfied
# 1  Neither satisfied nor dissatisfied
# 2                Moderately satisfied
# 3               Slightly dissatisfied
# 4                Moderately satisfied
#
#                                        HopeFiveYears  \
# 0  Working as a founder or co-founder of my own c...
# 1  Working in a different or more specialized tec...
# 2  Working as a founder or co-founder of my own c...
# 3  Working as a founder or co-founder of my own c...
# 4  Working in a different or more specialized tec...
#
#                                      JobSearchStatus  \
# 0  I’m not actively looking, but I am open to new...
# 1                    I am actively looking for a job
# 2  I’m not actively looking, but I am open to new...
# 3  I’m not actively looking, but I am open to new...
# 4  I’m not actively looking, but I am open to new...
#
#                   LastNewJob  AssessJob1  AssessJob2  AssessJob3  AssessJob4  \
# 0       Less than a year ago        10.0         7.0         8.0         1.0
# 1      More than 4 years ago         1.0         7.0        10.0         8.0
# 2       Less than a year ago         NaN         NaN         NaN         NaN
# 3       Less than a year ago         NaN         NaN         NaN         NaN
# 4  Between 1 and 2 years ago         8.0         5.0         7.0         1.0
#
#    AssessJob5  AssessJob6  AssessJob7  AssessJob8  AssessJob9  AssessJob10  \
# 0         2.0         5.0         3.0         4.0         9.0          6.0
# 1         2.0         5.0         4.0         3.0         6.0          9.0
# 2         NaN         NaN         NaN         NaN         NaN          NaN
# 3         NaN         NaN         NaN         NaN         NaN          NaN
# 4         2.0         6.0         4.0         3.0        10.0          9.0
#
#    AssessBenefits1  AssessBenefits2  AssessBenefits3  AssessBenefits4  \
# 0              NaN              NaN              NaN              NaN
# 1              1.0              5.0              3.0              7.0
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              1.0             10.0              2.0              4.0
#
#    AssessBenefits5  AssessBenefits6  AssessBenefits7  AssessBenefits8  \
# 0              NaN              NaN              NaN              NaN
# 1             10.0              4.0             11.0              9.0
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              8.0              3.0             11.0              7.0
#
#    AssessBenefits9  AssessBenefits10  AssessBenefits11  JobContactPriorities1  \
# 0              NaN               NaN               NaN                    3.0
# 1              6.0               2.0               8.0                    3.0
# 2              NaN               NaN               NaN                    NaN
# 3              NaN               NaN               NaN                    NaN
# 4              5.0               9.0               6.0                    2.0
#
#    JobContactPriorities2  JobContactPriorities3  JobContactPriorities4  \
# 0                    1.0                    4.0                    2.0
# 1                    1.0                    5.0                    2.0
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    1.0                    4.0                    5.0
#
#    JobContactPriorities5  JobEmailPriorities1  JobEmailPriorities2  \
# 0                    5.0                  5.0                  6.0
# 1                    4.0                  1.0                  3.0
# 2                    NaN                  NaN                  NaN
# 3                    NaN                  NaN                  NaN
# 4                    3.0                  7.0                  3.0
#
#    JobEmailPriorities3  JobEmailPriorities4  JobEmailPriorities5  \
# 0                  7.0                  2.0                  1.0
# 1                  4.0                  5.0                  2.0
# 2                  NaN                  NaN                  NaN
# 3                  NaN                  NaN                  NaN
# 4                  6.0                  2.0                  1.0
#
#    JobEmailPriorities6  JobEmailPriorities7  \
# 0                  4.0                  3.0
# 1                  6.0                  7.0
# 2                  NaN                  NaN
# 3                  NaN                  NaN
# 4                  4.0                  5.0
#
#                                          UpdateCV  \
# 0  My job status or other personal status changed
# 1               I saw an employer’s advertisement
# 2                                             NaN
# 3                        A recruiter contacted me
# 4  My job status or other personal status changed
#
#                       Currency  Salary SalaryType  ConvertedSalary  \
# 0                          NaN     NaN    Monthly              NaN
# 1  British pounds sterling (£)   51000     Yearly          70841.0
# 2                          NaN     NaN        NaN              NaN
# 3             U.S. dollars ($)     NaN        NaN              NaN
# 4      South African rands (R)  260000     Yearly          21426.0
#
#   CurrencySymbol                                 CommunicationTools  \
# 0            KES                                              Slack
# 1            GBP  Confluence;Office / productivity suite (Micros...
# 2            NaN                                                NaN
# 3            NaN                                                NaN
# 4            ZAR  Office / productivity suite (Microsoft Office,...
#
#    TimeFullyProductive                                     EducationTypes  \
# 0  One to three months  Taught yourself a new language, framework, or ...
# 1  One to three months  Taught yourself a new language, framework, or ...
# 2                  NaN                                                NaN
# 3  Three to six months  Completed an industry certification program (e...
# 4  Three to six months  Taken a part-time in-person course in programm...
#
#                                      SelfTaughtTypes TimeAfterBootcamp  \
# 0  The official documentation and/or standards fo...               NaN
# 1  The official documentation and/or standards fo...               NaN
# 2                                                NaN               NaN
# 3  The official documentation and/or standards fo...               NaN
# 4  The official documentation and/or standards fo...               NaN
#
#                    HackathonReasons  AgreeDisagree1  AgreeDisagree2  \
# 0  To build my professional network  Strongly agree  Strongly agree
# 1                               NaN           Agree           Agree
# 2                               NaN             NaN             NaN
# 3                               NaN        Disagree        Disagree
# 4                               NaN  Strongly agree           Agree
#
#                AgreeDisagree3  \
# 0  Neither Agree nor Disagree
# 1  Neither Agree nor Disagree
# 2                         NaN
# 3           Strongly disagree
# 4           Strongly disagree
#
#                                  LanguageWorkedWith  \
# 0                        JavaScript;Python;HTML;CSS
# 1                      JavaScript;Python;Bash/Shell
# 2                                               NaN
# 3  C#;JavaScript;SQL;TypeScript;HTML;CSS;Bash/Shell
# 4                C;C++;Java;Matlab;R;SQL;Bash/Shell
#
#                              LanguageDesireNextYear  \
# 0                        JavaScript;Python;HTML;CSS
# 1                                         Go;Python
# 2                                               NaN
# 3  C#;JavaScript;SQL;TypeScript;HTML;CSS;Bash/Shell
# 4              Assembly;C;C++;Matlab;SQL;Bash/Shell
#
#                                   DatabaseWorkedWith  \
# 0  Redis;SQL Server;MySQL;PostgreSQL;Amazon RDS/A...
# 1                         Redis;PostgreSQL;Memcached
# 2                                                NaN
# 3  SQL Server;Microsoft Azure (Tables, CosmosDB, ...
# 4               SQL Server;PostgreSQL;Oracle;IBM Db2
#
#                               DatabaseDesireNextYear  \
# 0  Redis;SQL Server;MySQL;PostgreSQL;Amazon RDS/A...
# 1                                         PostgreSQL
# 2                                                NaN
# 3  SQL Server;Microsoft Azure (Tables, CosmosDB, ...
# 4                          PostgreSQL;Oracle;IBM Db2
#
#                   PlatformWorkedWith             PlatformDesireNextYear  \
# 0           AWS;Azure;Linux;Firebase           AWS;Azure;Linux;Firebase
# 1                              Linux                              Linux
# 2                                NaN                                NaN
# 3                              Azure                              Azure
# 4  Arduino;Windows Desktop or Server  Arduino;Windows Desktop or Server
#
#   FrameworkWorkedWith  FrameworkDesireNextYear  \
# 0        Django;React             Django;React
# 1              Django                    React
# 2                 NaN                      NaN
# 3                 NaN  Angular;.NET Core;React
# 4                 NaN                      NaN
#
#                                           IDE OperatingSystem NumberMonitors  \
# 0               Komodo;Vim;Visual Studio Code     Linux-based              1
# 1          IPython / Jupyter;Sublime Text;Vim     Linux-based              2
# 2                                         NaN             NaN            NaN
# 3            Visual Studio;Visual Studio Code         Windows              2
# 4  Notepad++;Visual Studio;Visual Studio Code         Windows              2
#
#                                          Methodology     VersionControl  \
# 0                                        Agile;Scrum                Git
# 1                                                NaN     Git;Subversion
# 2                                                NaN                NaN
# 3                                 Agile;Kanban;Scrum                Git
# 4  Evidence-based software engineering;Formal sta...  Zip file back-ups
#
#                        CheckInCode AdBlocker AdBlockerDisable  \
# 0           Multiple times per day       Yes               No
# 1             A few times per week       Yes              Yes
# 2                              NaN       NaN              NaN
# 3           Multiple times per day       Yes              Yes
# 4  Weekly or a few times per month        No              NaN
#
#                                     AdBlockerReasons  \
# 0                                                NaN
# 1  The website I was visiting asked me to disable it
# 2                                                NaN
# 3  The ad-blocking software was causing display i...
# 4                                                NaN
#
#             AdsAgreeDisagree1           AdsAgreeDisagree2  \
# 0              Strongly agree              Strongly agree
# 1              Somewhat agree  Neither agree nor disagree
# 2                         NaN                         NaN
# 3  Neither agree nor disagree              Somewhat agree
# 4              Somewhat agree              Somewhat agree
#
#             AdsAgreeDisagree3  \
# 0              Strongly agree
# 1  Neither agree nor disagree
# 2                         NaN
# 3              Somewhat agree
# 4           Somewhat disagree
#
#                                           AdsActions  AdsPriorities1  \
# 0  Saw an online advertisement and then researche...             1.0
# 1                                                NaN             3.0
# 2                                                NaN             NaN
# 3  Stopped going to a website because of their ad...             NaN
# 4  Clicked on an online advertisement;Saw an onli...             2.0
#
#    AdsPriorities2  AdsPriorities3  AdsPriorities4  AdsPriorities5  \
# 0             5.0             4.0             7.0             2.0
# 1             5.0             1.0             4.0             6.0
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             3.0             4.0             6.0             1.0
#
#    AdsPriorities6  AdsPriorities7  \
# 0             6.0             3.0
# 1             7.0             2.0
# 2             NaN             NaN
# 3             NaN             NaN
# 4             7.0             5.0
#
#                                          AIDangerous  \
# 0  Artificial intelligence surpassing human intel...
# 1                      Increasing automation of jobs
# 2                                                NaN
# 3  Artificial intelligence surpassing human intel...
# 4              Algorithms making important decisions
#
#                                        AIInteresting  \
# 0              Algorithms making important decisions
# 1                      Increasing automation of jobs
# 2                                                NaN
# 3  Artificial intelligence surpassing human intel...
# 4              Algorithms making important decisions
#
#                                   AIResponsible  \
# 0  The developers or the people creating the AI
# 1  The developers or the people creating the AI
# 2                                           NaN
# 3       A governmental or other regulatory body
# 4  The developers or the people creating the AI
#
#                                             AIFuture           EthicsChoice  \
# 0  I'm excited about the possibilities more than ...                     No
# 1  I'm excited about the possibilities more than ...  Depends on what it is
# 2                                                NaN                    NaN
# 3  I don't care about it, or I haven't thought ab...                     No
# 4  I'm excited about the possibilities more than ...                     No
#
#                        EthicsReport  \
# 0                 Yes, and publicly
# 1             Depends on what it is
# 2                               NaN
# 3  Yes, but only within the company
# 4  Yes, but only within the company
#
#                               EthicsResponsible EthicalImplications  \
# 0  Upper management at the company/organization                 Yes
# 1  Upper management at the company/organization                 Yes
# 2                                           NaN                 NaN
# 3  Upper management at the company/organization                 Yes
# 4  Upper management at the company/organization                 Yes
#
#   StackOverflowRecommend               StackOverflowVisit  \
# 0       10 (Very Likely)           Multiple times per day
# 1       10 (Very Likely)  A few times per month or weekly
# 2                    NaN                              NaN
# 3       10 (Very Likely)             A few times per week
# 4       10 (Very Likely)            Daily or almost daily
#
#   StackOverflowHasAccount                           StackOverflowParticipate  \
# 0                     Yes  I have never participated in Q&A on Stack Over...
# 1                     Yes                    A few times per month or weekly
# 2                     NaN                                                NaN
# 3                     Yes                    A few times per month or weekly
# 4                     Yes                Less than once per month or monthly
#
#                                    StackOverflowJobs  \
# 0  No, I knew that Stack Overflow had a jobs boar...
# 1                                                Yes
# 2                                                NaN
# 3                                                Yes
# 4  No, I knew that Stack Overflow had a jobs boar...
#
#                         StackOverflowDevStory StackOverflowJobsRecommend  \
# 0                                         Yes                        NaN
# 1         No, I have one but it's out of date                          7
# 2                                         NaN                        NaN
# 3         No, I have one but it's out of date                          8
# 4  No, I know what it is but I don't have one                        NaN
#
#   StackOverflowConsiderMember       HypotheticalTools1  \
# 0                         Yes     Extremely interested
# 1                         Yes  A little bit interested
# 2                         NaN                      NaN
# 3                         Yes      Somewhat interested
# 4                         Yes     Extremely interested
#
#         HypotheticalTools2       HypotheticalTools3       HypotheticalTools4  \
# 0     Extremely interested     Extremely interested     Extremely interested
# 1  A little bit interested  A little bit interested  A little bit interested
# 2                      NaN                      NaN                      NaN
# 3      Somewhat interested      Somewhat interested      Somewhat interested
# 4     Extremely interested     Extremely interested     Extremely interested
#
#         HypotheticalTools5                WakeTime  HoursComputer  \
# 0     Extremely interested  Between 5:00 - 6:00 AM   9 - 12 hours
# 1  A little bit interested  Between 6:01 - 7:00 AM    5 - 8 hours
# 2                      NaN                     NaN            NaN
# 3      Somewhat interested  Between 6:01 - 7:00 AM   9 - 12 hours
# 4     Extremely interested          Before 5:00 AM  Over 12 hours
#
#            HoursOutside             SkipMeals             ErgonomicDevices  \
# 0           1 - 2 hours                 Never                Standing desk
# 1       30 - 59 minutes                 Never  Ergonomic keyboard or mouse
# 2                   NaN                   NaN                          NaN
# 3  Less than 30 minutes  3 - 4 times per week                          NaN
# 4           1 - 2 hours                 Never                          NaN
#
#                      Exercise Gender         SexualOrientation  \
# 0        3 - 4 times per week   Male  Straight or heterosexual
# 1   Daily or almost every day   Male  Straight or heterosexual
# 2                         NaN    NaN                       NaN
# 3  I don't typically exercise   Male  Straight or heterosexual
# 4        3 - 4 times per week   Male  Straight or heterosexual
#
#                                     EducationParents  \
# 0           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2                                                NaN
# 3  Some college/university study without earning ...
# 4  Some college/university study without earning ...
#
#                   RaceEthnicity                Age Dependents MilitaryUS  \
# 0   Black or of African descent  25 - 34 years old        Yes        NaN
# 1  White or of European descent  35 - 44 years old        Yes        NaN
# 2                           NaN                NaN        NaN        NaN
# 3  White or of European descent  35 - 44 years old         No         No
# 4  White or of European descent  18 - 24 years old        Yes        NaN
#
#                           SurveyTooLong     SurveyEasy
# 0  The survey was an appropriate length      Very easy
# 1  The survey was an appropriate length  Somewhat easy
# 2                                   NaN            NaN
# 3  The survey was an appropriate length  Somewhat easy
# 4  The survey was an appropriate length  Somewhat easy
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# 3                      Employed full-time
# 4                      Employed full-time
#
#                                      FormalEducation  \
# 0                                   Secondary school
# 1  Some college/university study without earning ...
# 2                                  Bachelor's degree
# 3                                    Doctoral degree
# 4                                    Master's degree
#
#                                   MajorUndergrad  \
# 0                                            NaN
# 1       Computer science or software engineering
# 2       Computer science or software engineering
# 3  A non-computer-focused engineering discipline
# 4       Computer science or software engineering
#
#                                           HomeRemote  \
# 0                                                NaN
# 1              More than half, but not all, the time
# 2  Less than half the time, but at least one day ...
# 3  Less than half the time, but at least one day ...
# 4                                              Never
#
#                 CompanySize  \
# 0                       NaN
# 1        20 to 99 employees
# 2  10,000 or more employees
# 3  10,000 or more employees
# 4        10 to 19 employees
#
#                                          CompanyType      YearsProgram  \
# 0                                                NaN      2 to 3 years
# 1  Privately-held limited company, not in startup...     9 to 10 years
# 2                        Publicly-traded corporation  20 or more years
# 3  Non-profit/non-governmental organization or pr...    14 to 15 years
# 4  Privately-held limited company, not in startup...  20 or more years
#
#       YearsCodedJob YearsCodedJobPast  \
# 0               NaN               NaN
# 1               NaN               NaN
# 2  20 or more years               NaN
# 3     9 to 10 years               NaN
# 4    10 to 11 years               NaN
#
#                                        DeveloperType WebDeveloperType  \
# 0                                                NaN              NaN
# 1                                                NaN              NaN
# 2                                              Other              NaN
# 3                                                NaN              NaN
# 4  Mobile developer; Graphics programming; Deskto...              NaN
#
#   MobileDeveloperType NonDeveloperType  CareerSatisfaction  JobSatisfaction  \
# 0                 NaN              NaN                 NaN              NaN
# 1                 NaN              NaN                 NaN              NaN
# 2                 NaN              NaN                 8.0              9.0
# 3                 NaN   Data scientist                 6.0              3.0
# 4                 NaN              NaN                 6.0              8.0
#
#   ExCoderReturn ExCoderNotForMe ExCoderBalance ExCoder10Years ExCoderBelonged  \
# 0           NaN             NaN            NaN            NaN             NaN
# 1           NaN             NaN            NaN            NaN             NaN
# 2           NaN             NaN            NaN            NaN             NaN
# 3           NaN             NaN            NaN            NaN             NaN
# 4           NaN             NaN            NaN            NaN             NaN
#
#   ExCoderSkills ExCoderWillNotCode ExCoderActive  \
# 0           NaN                NaN           NaN
# 1           NaN                NaN           NaN
# 2           NaN                NaN           NaN
# 3           NaN                NaN           NaN
# 4           NaN                NaN           NaN
#
#                    PronounceGIF  ProblemSolving  BuildingThings  \
# 0  With a soft "g," like "jiff"  Strongly agree  Strongly agree
# 1  With a hard "g," like "gift"             NaN             NaN
# 2  With a hard "g," like "gift"  Strongly agree  Strongly agree
# 3  With a soft "g," like "jiff"  Strongly agree  Strongly agree
# 4  With a soft "g," like "jiff"             NaN             NaN
#
#   LearningNewTech   BoringDetails     JobSecurity DiversityImportant  \
# 0           Agree        Disagree  Strongly agree              Agree
# 1             NaN             NaN             NaN                NaN
# 2  Strongly agree  Somewhat agree           Agree     Strongly agree
# 3  Strongly agree        Disagree  Somewhat agree              Agree
# 4             NaN             NaN             NaN                NaN
#
#   AnnoyingUI FriendsDevelopers   RightWrongWay UnderstandComputers  \
# 0      Agree          Disagree  Somewhat agree            Disagree
# 1        NaN               NaN             NaN                 NaN
# 2      Agree    Somewhat agree        Disagree            Disagree
# 3      Agree             Agree  Somewhat agree   Strongly disagree
# 4        NaN               NaN             NaN                 NaN
#
#       SeriousWork InvestTimeTools        WorkPayCare KinshipDevelopers  \
# 0  Strongly agree  Strongly agree  Strongly disagree             Agree
# 1             NaN             NaN                NaN               NaN
# 2           Agree  Somewhat agree           Disagree    Somewhat agree
# 3  Strongly agree           Agree           Disagree    Strongly agree
# 4             NaN             NaN                NaN               NaN
#
#   ChallengeMyself    CompetePeers ChangeWorld  \
# 0           Agree        Disagree       Agree
# 1             NaN             NaN         NaN
# 2           Agree        Disagree       Agree
# 3  Strongly agree  Somewhat agree       Agree
# 4             NaN             NaN         NaN
#
#                                     JobSeekingStatus  HoursPerWeek  \
# 0  I'm not actively looking, but I am open to new...           0.0
# 1                                                NaN           NaN
# 2                                                NaN           NaN
# 3                    I am actively looking for a job           5.0
# 4                                                NaN           NaN
#
#                   LastNewJob   AssessJobIndustry       AssessJobRole  \
# 0      Not applicable/ never      Very important      Very important
# 1                        NaN                 NaN                 NaN
# 2                        NaN                 NaN                 NaN
# 3  Between 2 and 4 years ago  Somewhat important  Somewhat important
# 4                        NaN                 NaN                 NaN
#
#          AssessJobExp   AssessJobDept   AssessJobTech AssessJobProjects  \
# 0           Important  Very important  Very important    Very important
# 1                 NaN             NaN             NaN               NaN
# 2                 NaN             NaN             NaN               NaN
# 3  Somewhat important       Important       Important    Very important
# 4                 NaN             NaN             NaN               NaN
#
#   AssessJobCompensation AssessJobOffice AssessJobCommute     AssessJobRemote  \
# 0             Important  Very important   Very important      Very important
# 1                   NaN             NaN              NaN                 NaN
# 2                   NaN             NaN              NaN                 NaN
# 3             Important  Very important        Important  Somewhat important
# 4                   NaN             NaN              NaN                 NaN
#
#      AssessJobLeaders AssessJobProfDevel  AssessJobDiversity  \
# 0      Very important     Very important  Somewhat important
# 1                 NaN                NaN                 NaN
# 2                 NaN                NaN                 NaN
# 3  Not very important     Very important           Important
# 4                 NaN                NaN                 NaN
#
#      AssessJobProduct   AssessJobFinances  \
# 0  Not very important  Somewhat important
# 1                 NaN                 NaN
# 2                 NaN                 NaN
# 3      Very important      Very important
# 4                 NaN                 NaN
#
#                                    ImportantBenefits ClickyKeys  \
# 0   Stock options; Vacation/days off; Remote options        Yes
# 1                                                NaN         No
# 2                                                NaN        Yes
# 3  Stock options; Annual bonus; Health benefits; ...        Yes
# 4                                                NaN        NaN
#
#         JobProfile ResumePrompted  \
# 0            Other            NaN
# ...
# 0                                              Great
# 1                                              Great
# 2                                              Great
# 3                                              Great
# 4                                           Tolerate
#
#   Who do you want to communicate with about a new job opportunity: Developer  \
# 0                                              Great
# 1                                              Great
# 2                                              Great
# 3                                              Great
# 4                                              Great
#
#   How can companies improve interview process: More live code  \
# 0                             Show meæmore live code
# 1                                                NaN
# 2                                                NaN
# 3                             Show meæmore live code
# 4                                                NaN
#
#   How can companies improve interview process: Flexible interview schedule  \
# 0                                                NaN
# 1        Be more flexible about interview scheduling
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   How can companies improve interview process: Remote interviews  \
# 0  Offer remote interviews (ie. via video confere...
# 1  Offer remote interviews (ie. via video confere...
# 2                                                NaN
# 3                                                NaN
# 4  Offer remote interviews (ie. via video confere...
#
#   How can companies improve interview process: Introduce me to boss  \
# 0                           Introduce me to the boss
# 1                                                NaN
# 2                           Introduce me to the boss
# 3                                                NaN
# 4                                                NaN
#
#   How can companies improve interview process: Introduce me to team  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   How can companies improve interview process: Gimme coffee  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   How can companies improve interview process: Show me workplace  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3             Show me the space in which I will work
# 4                                                NaN
#
#   How can companies improve interview process: Fewer brainteasers  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                 Fewer brainteasers
#
#   How can companies improve interview process: Better preparation  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3         Prepare me for who I will be speaking with
# 4         Prepare me for who I will be speaking with
#
#   Why try Stack Overflow Careers: No spam  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Why try Stack Overflow Careers: Jobs site for programmers  \
# 0      It's a jobs site specificallyæfor programmers
# 1      It's a jobs site specificallyæfor programmers
# 2                                                NaN
# 3      It's a jobs site specificallyæfor programmers
# 4                                                NaN
#
#   Why try Stack Overflow Careers: Selection of revelant jobs  \
# 0                    Goodæselection of relevant jobs
# 1                    Goodæselection of relevant jobs
# 2                    Goodæselection of relevant jobs
# 3                                                NaN
# 4                                                NaN
#
#   Why try Stack Overflow Careers: Showcase Stack Overflow activity  \
# 0             To showcase my Stack Overflow activity
# 1                                                NaN
# 2                                                NaN
# 3             To showcase my Stack Overflow activity
# 4                                                NaN
#
#   Why try Stack Overflow Careers: Jobs are on Stack Overflow  \
# 0  Because the jobs ads are right there on Stack ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Why try Stack Overflow Careers: Other  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   How many caffeinated beverages per day?  \
# 0                                       0
# 1                                       3
# 2                                       4
# 3                                       2
# 4                                       6
#
#   How many hours programming as hobby per week?  \
# 0                           5-10 hours per week
# 1                            2-5 hours per week
# 2                           5-10 hours per week
# 3                           5-10 hours per week
# 4                           5-10 hours per week
#
#   How frequently land on or read Stack Overflow Preferred text editor  \
# 0                          Multipleætimes a day          Sublime Text
# 1                                    Once a day                   NaN
# 2                                    Once a day                XEmacs
# 3                          Multipleætimes a day          Sublime Text
# 4                          Multipleætimes a day          Sublime Text
#
#   Preferred text editor: write-in Prefered IDE theme Source control used: Git  \
# 0                             NaN               Dark                      NaN
# 1              Visual Studio 2013              Light                      Git
# 2                             NaN               Dark                      NaN
# 3                             NaN               Dark                      Git
# 4                             NaN               Dark                      Git
#
#   Source control used: Mercurial Source control used: SVN  \
# 0                      Mercurial                      NaN
# 1                            NaN                      NaN
# 2                            NaN                      SVN
# 3                            NaN                      SVN
# 4                            NaN                      NaN
#
#   Source control used: CVS Source control used: Perforce  \
# 0                      NaN                           NaN
# 1                      NaN                           NaN
# 2                      NaN                           NaN
# 3                      NaN                           NaN
# 4                      NaN                           NaN
#
#   Source control used: TFS Source control used: DCVS  \
# 0                      NaN                       NaN
# 1                      TFS                       NaN
# 2                      NaN                       NaN
# 3                      NaN                       NaN
# 4                      TFS                       NaN
#
#   Source control used: Bitkeeper Source control used: Legacy / Custom  \
# 0                            NaN                                  NaN
# 1                            NaN                                  NaN
# 2                            NaN                                  NaN
# 3                            NaN                                  NaN
# 4                            NaN                                  NaN
#
#   Source control used: I don't use source control  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   Source control used: write-in Prefered Source Control  \
# 0                           NaN               Mercurial
# 1                           NaN                     TFS
# 2                           NaN                     SVN
# 3                           NaN                     Git
# 4                           NaN                     Git
#
#   Prefered Source Control: write-in Why use Stack Overflow: Help for job  \
# 0                               NaN               To get help for my job
# 1                               NaN               To get help for my job
# 2                               NaN                                  NaN
# 3                               NaN               To get help for my job
# 4                               NaN               To get help for my job
#
#   Why use Stack Overflow: To give help  \
# 0               To give help to others
# 1               To give help to others
# 2                                  NaN
# 3               To give help to others
# 4                                  NaN
#
#   Why use Stack Overflow: Can't do job without it  \
# 0            Because I can't do my job without it
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   Why use Stack Overflow: Maintain online presence  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Why use Stack Overflow: Demonstrate expertise  \
# 0     To demonstrate that I'm good at what I do
# 1                                           NaN
# 2                                           NaN
# 3     To demonstrate that I'm good at what I do
# 4                                           NaN
#
#   Why use Stack Overflow: Communicate with others  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3              To communicate with others like me
# 4                                             NaN
#
#   Why use Stack Overflow: Receive help on personal projects  \
# 0            To receive help onæmy personal projects
# 1            To receive help onæmy personal projects
# 2            To receive help onæmy personal projects
# 3                                                NaN
# 4                                                NaN
#
#   Why use Stack Overflow: Love to learn  \
# 0               Because I love to learn
# 1                                   NaN
# 2                                   NaN
# 3               Because I love to learn
# 4               Because I love to learn
#
#   Why use Stack Overflow: I don't use Stack Overflow  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   How often are Stack Overflow's answers helpful  \
# 0                                        Usually
# 1                                        Usually
# 2                                         Rarely
# 3                                        Usually
# 4                                        Usually
#
#         Why answer: Help a programmer in need  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3  It feels good to help a programmer in need
# 4  It feels good to help a programmer in need
#
#                  Why answer: Help future programmers  \
# 0                                                NaN
# 1  My answer will help lots of people who have th...
# 2                                                NaN
# 3  My answer will help lots of people who have th...
# 4                                                NaN
#
#             Why answer: Demonstrate expertise  \
# 0  It feels good to demonstrate my expertise.
# 1  It feels good to demonstrate my expertise.
# 2                                         NaN
# 3  It feels good to demonstrate my expertise.
# 4                                         NaN
#
#                    Why answer: Self promotion  \
# 0  Demonstrating my expertise will benefit me
# 1                                         NaN
# 2  Demonstrating my expertise will benefit me
# 3  Demonstrating my expertise will benefit me
# 4  Demonstrating my expertise will benefit me
#
#    Why answer: Sense of responsibility to developers Why answer: No idea  \
# 0  I feel a sense of responsibility to the develo...                 NaN
# 1                                                NaN                 NaN
# 2                                                NaN                 NaN
# 3  I feel a sense of responsibility to the develo...                 NaN
# 4                                                NaN                 NaN
#
#   Why answer: I don't answer and I don't want to  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#             Why answer: I don't answer but I want to
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  I don't answer much (or at all), but I want to...

# %%
display(df2016.info())

# %%
df2015_mix = df2015.loc[:,'Current Lang & Tech: Android':'Current Lang & Tech: Write-In']
df2015_mix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26086 entries, 0 to 26085
# Data columns (total 43 columns):
# Current Lang & Tech: Android          4110 non-null object
# Current Lang & Tech: Arduino          1626 non-null object
# Current Lang & Tech: AngularJS        2913 non-null object
# Current Lang & Tech: C                3612 non-null object
# Current Lang & Tech: C++              4529 non-null object
# Current Lang & Tech: C++11            1851 non-null object
# Current Lang & Tech: C#               6949 non-null object
# Current Lang & Tech: Cassandra        202 non-null object
# Current Lang & Tech: CoffeeScript     783 non-null object
# Current Lang & Tech: Cordova          628 non-null object
# Current Lang & Tech: Clojure          176 non-null object
# Current Lang & Tech: Cloud            1410 non-null object
# Current Lang & Tech: Dart             109 non-null object
# Current Lang & Tech: F#               174 non-null object
# Current Lang & Tech: Go               462 non-null object
# Current Lang & Tech: Hadoop           342 non-null object
# Current Lang & Tech: Haskell          357 non-null object
# Current Lang & Tech: iOS              1956 non-null object
# Current Lang & Tech: Java             8219 non-null object
# Current Lang & Tech: JavaScript       11962 non-null object
# Current Lang & Tech: LAMP             1926 non-null object
# Current Lang & Tech: Matlab           860 non-null object
# Current Lang & Tech: MongoDB          1745 non-null object
# Current Lang & Tech: Node.js          2919 non-null object
# Current Lang & Tech: Objective-C      1719 non-null object
# Current Lang & Tech: Perl             738 non-null object
# Current Lang & Tech: PHP              6529 non-null object
# Current Lang & Tech: Python           5238 non-null object
# Current Lang & Tech: R                755 non-null object
# Current Lang & Tech: Redis            873 non-null object
# Current Lang & Tech: Ruby             1765 non-null object
# Current Lang & Tech: Rust             103 non-null object
# Current Lang & Tech: Salesforce       153 non-null object
# Current Lang & Tech: Scala            538 non-null object
# Current Lang & Tech: Sharepoint       349 non-null object
# Current Lang & Tech: Spark            104 non-null object
# Current Lang & Tech: SQL              9439 non-null object
# Current Lang & Tech: SQL Server       4129 non-null object
# Current Lang & Tech: Swift            759 non-null object
# Current Lang & Tech: Visual Basic     1701 non-null object
# Current Lang & Tech: Windows Phone    570 non-null object
# Current Lang & Tech: Wordpress        2007 non-null object
# Current Lang & Tech: Write-In         2148 non-null object
# dtypes: object(43)
# memory usage: 8.6+ MB

# %%
df2015_mix.columns = df2015_mix.columns.str.replace('Current Lang & Tech: ', '')
#df2015_mix.columns = df2015_mix.columns.str.casefold()

# %%
df2015_mix.head()
# Out:
#   Android Arduino AngularJS    C  C++ C++11   C# Cassandra CoffeeScript  \
# 0     NaN     NaN       NaN  NaN  NaN   NaN  NaN       NaN          NaN
# 1     NaN     NaN       NaN  NaN  NaN   NaN   C#       NaN          NaN
# 2     NaN     NaN       NaN  NaN  NaN   NaN   C#       NaN          NaN
# 3     NaN     NaN       NaN  NaN  NaN   NaN  NaN       NaN          NaN
# 4     NaN     NaN       NaN  NaN  NaN   NaN   C#       NaN          NaN
#
#   Cordova Clojure Cloud Dart   F#   Go Hadoop Haskell  iOS  Java  JavaScript  \
# 0     NaN     NaN   NaN  NaN  NaN  NaN    NaN     NaN  NaN  Java         NaN
# 1     NaN     NaN   NaN  NaN  NaN  NaN    NaN     NaN  NaN   NaN         NaN
# 2     NaN     NaN   NaN  NaN  NaN  NaN    NaN     NaN  NaN   NaN         NaN
# 3     NaN     NaN   NaN  NaN  NaN  NaN    NaN     NaN  NaN   NaN  JavaScript
# 4     NaN     NaN   NaN  NaN  NaN   Go    NaN     NaN  NaN   NaN         NaN
#
#    LAMP Matlab MongoDB  Node.js Objective-C Perl  PHP  Python    R  Redis  \
# 0   NaN    NaN     NaN      NaN         NaN  NaN  NaN     NaN  NaN    NaN
# 1   NaN    NaN     NaN      NaN         NaN  NaN  NaN     NaN  NaN    NaN
# 2   NaN    NaN     NaN      NaN         NaN  NaN  NaN     NaN  NaN    NaN
# 3  LAMP    NaN     NaN  Node.js         NaN  NaN  PHP  Python  NaN  Redis
# 4   NaN    NaN     NaN      NaN         NaN  NaN  NaN     NaN  NaN    NaN
#
#   Ruby Rust Salesforce  Scala Sharepoint Spark  SQL SQL Server Swift  \
# 0  NaN  NaN        NaN  Scala        NaN   NaN  NaN        NaN   NaN
# 1  NaN  NaN        NaN    NaN        NaN   NaN  NaN        NaN   NaN
# 2  NaN  NaN        NaN    NaN        NaN   NaN  NaN        NaN   NaN
# 3  NaN  NaN        NaN    NaN        NaN   NaN  SQL        NaN   NaN
# 4  NaN  NaN        NaN    NaN        NaN   NaN  NaN        NaN   NaN
#
#   Visual Basic Windows Phone Wordpress Write-In
# 0          NaN           NaN       NaN      NaN
# 1          NaN           NaN       NaN      NaN
# 2          NaN           NaN       NaN      NaN
# 3          NaN           NaN       NaN      lua
# 4          NaN           NaN       NaN      NaN

# %%
df2015_mix.head()
len(df2015_mix.columns)
# Out:
# 43

# %%
list_lang_comm = ['Visual Basic / VBA', 'Java', 'Objective-C', 'Go', 'C++', 'C', 'PHP', 'Rust', 'Ruby', 'C#', 'R', 'Clojure', 'F#', 'Swift', 'Scala', 'Python', 'JavaScript', 'SQL']

not_lang_list = ['Android',
 'AngularJS',
 'Arduino',
 'Arduino / Raspberry Pi',
 'CSS',
 'Cassandra',
 'Cloud',
 'Cloud (AWS, GAE, Azure, etc.)',
 'Cordova',
 'HTML',
 'HTML/CSS',
 'Hadoop',
 'LAMP',
 'MongoDB',
 'Node.js',
 'ReactJS',
 'Redis',
 'SQL Server',
 'Salesforce',
 'SharePoint',
 'Spark',
 'Windows Phone',
 'Wordpress',
 'Write-In',
 'iOS']
not_lang_list
# Out:
# ['Android',
#  'AngularJS',
#  'Arduino',
#  'Arduino / Raspberry Pi',
#  'CSS',
#  'Cassandra',
#  'Cloud',
#  'Cloud (AWS, GAE, Azure, etc.)',
#  'Cordova',
#  'HTML',
#  'HTML/CSS',
#  'Hadoop',
#  'LAMP',
#  'MongoDB',
#  'Node.js',
#  'ReactJS',
#  'Redis',
#  'SQL Server',
#  'Salesforce',
#  'SharePoint',
#  'Spark',
#  'Windows Phone',
#  'Wordpress',
#  'Write-In',
#  'iOS']

# %%
list_lang_comm.sort()
list_lang_comm
# Out:
# ['C',
#  'C#',
#  'C++',
#  'Clojure',
#  'F#',
#  'Go',
#  'Java',
#  'JavaScript',
#  'Objective-C',
#  'PHP',
#  'Python',
#  'R',
#  'Ruby',
#  'Rust',
#  'SQL',
#  'Scala',
#  'Swift',
#  'Visual Basic / VBA']

# %%
'''
from collections import defaultdict
new_df = defaultdict(int)
    #loop through list of ed types
for val in not_lang_list:
        #loop through rows
    for idx in range(df2015_mix.shape[0]):
            #if the ed type is in the row add 1
        if val in df2015_mix.columns[idx]:
            new_df[val] += int(df2015_mix[idx])
#new_df = pd.DataFrame(pd.Series(new_df)).reset_index()
new_df.columns = [col1, col2]
#new_df.sort_values('count', ascending=False, inplace=True)

# %%
#test
#df2015_mix = df2015_mix.drop('C', axis = 1)

# %%
'''
#finds common values in the Language columns of each annual dataframe
lang15_todrop = list(set(not_lang_list).intersection(set(df2015_mix.columns)))
print(len(lang15_todrop), lang15_todrop)
# Out:
# 9 ['Cassandra', 'MongoDB', 'Arduino', 'Android', 'Redis', 'Node.js', 'Hadoop', 'Cordova', 'iOS']

# %%
df2015_mix_dropped.head()
# Out:
#   Android Arduino AngularJS    C  C++ C++11   C# Cassandra CoffeeScript  \
# 0     NaN     NaN       NaN  NaN  NaN   NaN  NaN       NaN          NaN
# 1     NaN     NaN       NaN  NaN  NaN   NaN   C#       NaN          NaN
# 2     NaN     NaN       NaN  NaN  NaN   NaN   C#       NaN          NaN
# 3     NaN     NaN       NaN  NaN  NaN   NaN  NaN       NaN          NaN
# 4     NaN     NaN       NaN  NaN  NaN   NaN   C#       NaN          NaN
#
#   Cordova Clojure Cloud Dart   F#   Go Hadoop Haskell  iOS  Java  JavaScript  \
# 0     NaN     NaN   NaN  NaN  NaN  NaN    NaN     NaN  NaN  Java         NaN
# 1     NaN     NaN   NaN  NaN  NaN  NaN    NaN     NaN  NaN   NaN         NaN
# 2     NaN     NaN   NaN  NaN  NaN  NaN    NaN     NaN  NaN   NaN         NaN
# 3     NaN     NaN   NaN  NaN  NaN  NaN    NaN     NaN  NaN   NaN  JavaScript
# 4     NaN     NaN   NaN  NaN  NaN   Go    NaN     NaN  NaN   NaN         NaN
#
#    LAMP Matlab MongoDB  Node.js Objective-C Perl  PHP  Python    R  Redis  \
# 0   NaN    NaN     NaN      NaN         NaN  NaN  NaN     NaN  NaN    NaN
# 1   NaN    NaN     NaN      NaN         NaN  NaN  NaN     NaN  NaN    NaN
# 2   NaN    NaN     NaN      NaN         NaN  NaN  NaN     NaN  NaN    NaN
# 3  LAMP    NaN     NaN  Node.js         NaN  NaN  PHP  Python  NaN  Redis
# 4   NaN    NaN     NaN      NaN         NaN  NaN  NaN     NaN  NaN    NaN
#
#   Ruby Rust Salesforce  Scala Sharepoint Spark  SQL SQL Server Swift  \
# 0  NaN  NaN        NaN  Scala        NaN   NaN  NaN        NaN   NaN
# 1  NaN  NaN        NaN    NaN        NaN   NaN  NaN        NaN   NaN
# 2  NaN  NaN        NaN    NaN        NaN   NaN  NaN        NaN   NaN
# 3  NaN  NaN        NaN    NaN        NaN   NaN  SQL        NaN   NaN
# 4  NaN  NaN        NaN    NaN        NaN   NaN  NaN        NaN   NaN
#
#   Visual Basic Windows Phone Wordpress Write-In
# 0          NaN           NaN       NaN      NaN
# 1          NaN           NaN       NaN      NaN
# 2          NaN           NaN       NaN      NaN
# 3          NaN           NaN       NaN      lua
# 4          NaN           NaN       NaN      NaN

# %%
for item in not_lang_list:
    for col in df2015_mix_dropped.columns:
        if item.casefold() == col.casefold():
            df2015_mix_dropped = df2015_mix_dropped.drop(col, axis = 1)

# %%
df2015_mix_dropped.shape
# Out:
# (26086, 24)

# %%
def clean_df_cat(df, to_remove):
    for item in to_remove:
        for col in df.columns:
            if item.casefold() == col.casefold():
                df = df.drop(col, axis = 1)
    return df

# %%
df2015_mix.shape
# Out:
# (26086, 43)

# %%
dflang2015 = clean_df_cat(df2015_mix, not_lang_list)
dflang2015.shape
# Out:
# (26086, 24)

# %%
dflang2015 = dflang2015.rename(columns = {"C++": "C++_ini", 
                                                        "Visual Basic": "Visual Basic / VBA"})
dflang2015.head()
# Out:
#      C C++_ini C++11   C# CoffeeScript Clojure Dart   F#   Go Haskell  Java  \
# 0  NaN     NaN   NaN  NaN          NaN     NaN  NaN  NaN  NaN     NaN  Java
# 1  NaN     NaN   NaN   C#          NaN     NaN  NaN  NaN  NaN     NaN   NaN
# 2  NaN     NaN   NaN   C#          NaN     NaN  NaN  NaN  NaN     NaN   NaN
# 3  NaN     NaN   NaN  NaN          NaN     NaN  NaN  NaN  NaN     NaN   NaN
# 4  NaN     NaN   NaN   C#          NaN     NaN  NaN  NaN   Go     NaN   NaN
#
#    JavaScript Matlab Objective-C Perl  PHP  Python    R Ruby Rust  Scala  SQL  \
# 0         NaN    NaN         NaN  NaN  NaN     NaN  NaN  NaN  NaN  Scala  NaN
# 1         NaN    NaN         NaN  NaN  NaN     NaN  NaN  NaN  NaN    NaN  NaN
# 2         NaN    NaN         NaN  NaN  NaN     NaN  NaN  NaN  NaN    NaN  NaN
# 3  JavaScript    NaN         NaN  NaN  PHP  Python  NaN  NaN  NaN    NaN  SQL
# 4         NaN    NaN         NaN  NaN  NaN     NaN  NaN  NaN  NaN    NaN  NaN
#
#   Swift Visual Basic / VBA
# 0   NaN                NaN
# 1   NaN                NaN
# 2   NaN                NaN
# 3   NaN                NaN
# 4   NaN                NaN

# %%
dflang2015['C++'] = dflang2015['C++'].replace(0, np.nan)
dflang2015['Other(s)'] = dflang2015['Other(s)'].replace(False, np.nan)
dflang2015.head(n = 30)
# Out:
#       C   C#  Clojure   F#   Go  Java  JavaScript  Objective-C  PHP  Python  \
# 0   NaN  NaN      NaN  NaN  NaN  Java         NaN          NaN  NaN     NaN
# 1   NaN   C#      NaN  NaN  NaN   NaN         NaN          NaN  NaN     NaN
# 2   NaN   C#      NaN  NaN  NaN   NaN         NaN          NaN  NaN     NaN
# 3   NaN  NaN      NaN  NaN  NaN   NaN  JavaScript          NaN  PHP  Python
# 4   NaN   C#      NaN  NaN   Go   NaN         NaN          NaN  NaN     NaN
# 5   NaN   C#      NaN  NaN  NaN   NaN  JavaScript          NaN  NaN     NaN
# 6   NaN  NaN      NaN  NaN  NaN  Java  JavaScript          NaN  PHP     NaN
# 7   NaN  NaN      NaN  NaN  NaN   NaN  JavaScript          NaN  NaN  Python
# 8   NaN   C#      NaN  NaN  NaN   NaN  JavaScript          NaN  NaN     NaN
# 9   NaN   C#      NaN  NaN  NaN   NaN         NaN          NaN  PHP     NaN
# 10  NaN  NaN      NaN  NaN  NaN  Java         NaN  Objective-C  NaN     NaN
# 11  NaN   C#      NaN  NaN  NaN   NaN         NaN          NaN  PHP     NaN
# 12  NaN   C#      NaN  NaN  NaN   NaN  JavaScript          NaN  NaN  Python
# 13    C  NaN      NaN  NaN  NaN  Java         NaN          NaN  NaN  Python
# 14  NaN   C#      NaN  NaN  NaN   NaN         NaN          NaN  NaN     NaN
# 15    C   C#      NaN  NaN  NaN  Java  JavaScript  Objective-C  NaN     NaN
# 16  NaN  NaN      NaN  NaN  NaN   NaN         NaN          NaN  NaN     NaN
# 17  NaN  NaN      NaN  NaN  NaN  Java  JavaScript          NaN  NaN     NaN
# 18  NaN   C#      NaN  NaN  NaN   NaN         NaN          NaN  NaN     NaN
# 19  NaN  NaN      NaN  NaN  NaN   NaN  JavaScript          NaN  PHP     NaN
# 20  NaN   C#      NaN  NaN  NaN   NaN  JavaScript          NaN  NaN     NaN
# 21  NaN   C#      NaN  NaN  NaN   NaN         NaN          NaN  NaN     NaN
# 22  NaN  NaN      NaN  NaN  NaN   NaN         NaN          NaN  NaN     NaN
# 23  NaN   C#      NaN  NaN  NaN   NaN  JavaScript          NaN  PHP     NaN
# 24  NaN  NaN  Clojure  NaN  NaN   NaN  JavaScript          NaN  PHP     NaN
# 25  NaN   C#      NaN  NaN  NaN   NaN  JavaScript          NaN  NaN     NaN
# 26  NaN  NaN      NaN  NaN  NaN   NaN  JavaScript          NaN  PHP  Python
# 27  NaN  NaN      NaN  NaN  NaN  Java         NaN          NaN  NaN     NaN
# 28  NaN   C#      NaN  NaN  NaN   NaN         NaN          NaN  NaN  Python
# 29  NaN  NaN      NaN  NaN  NaN  Java         NaN          NaN  NaN     NaN
#
#       R  Ruby Rust  Scala  SQL Swift Visual Basic / VBA  C++  Other(s)
# 0   NaN   NaN  NaN  Scala  NaN   NaN                NaN  NaN       NaN
# 1   NaN   NaN  NaN    NaN  NaN   NaN                NaN  NaN       NaN
# 2   NaN   NaN  NaN    NaN  NaN   NaN                NaN  NaN       NaN
# 3   NaN   NaN  NaN    NaN  SQL   NaN                NaN  NaN       NaN
# 4   NaN   NaN  NaN    NaN  NaN   NaN                NaN  NaN       NaN
# 5   NaN   NaN  NaN    NaN  NaN   NaN                NaN  NaN       NaN
# 6   NaN   NaN  NaN    NaN  SQL   NaN                NaN  NaN       NaN
# 7   NaN  Ruby  NaN    NaN  SQL   NaN                NaN  NaN       NaN
# 8   NaN   NaN  NaN    NaN  NaN   NaN                NaN  NaN       NaN
# 9   NaN   NaN  NaN    NaN  NaN   NaN                NaN  NaN       NaN
# 10  NaN   NaN  NaN    NaN  NaN   NaN                NaN  NaN       NaN
# 11  NaN   NaN  NaN    NaN  NaN   NaN                NaN  NaN       NaN
# 12  NaN   NaN  NaN    NaN  NaN   NaN                NaN  NaN       NaN
# 13  NaN   NaN  NaN    NaN  NaN   NaN                NaN  NaN       NaN
# 14  NaN   NaN  NaN    NaN  NaN   NaN                NaN  NaN       NaN
# 15  NaN   NaN  NaN    NaN  SQL   NaN                NaN  1.0       NaN
# 16  NaN   NaN  NaN    NaN  SQL   NaN                NaN  NaN       NaN
# 17  NaN   NaN  NaN    NaN  NaN   NaN                NaN  NaN       NaN
# 18  NaN   NaN  NaN    NaN  SQL   NaN                NaN  NaN       NaN
# 19  NaN   NaN  NaN    NaN  SQL   NaN                NaN  NaN       NaN
# 20  NaN   NaN  NaN    NaN  SQL   NaN                NaN  NaN       NaN
# 21  NaN   NaN  NaN    NaN  NaN   NaN                NaN  NaN       1.0
# 22  NaN   NaN  NaN    NaN  NaN   NaN                NaN  NaN       NaN
# 23  NaN   NaN  NaN    NaN  NaN   NaN                NaN  NaN       NaN
# 24  NaN   NaN  NaN    NaN  SQL   NaN                NaN  NaN       NaN
# 25  NaN   NaN  NaN    NaN  SQL   NaN                NaN  NaN       NaN
# 26  NaN   NaN  NaN    NaN  SQL   NaN                NaN  NaN       NaN
# 27  NaN   NaN  NaN    NaN  NaN   NaN                NaN  NaN       NaN
# 28  NaN   NaN  NaN    NaN  SQL   NaN                NaN  NaN       NaN
# 29  NaN   NaN  NaN    NaN  NaN   NaN                NaN  NaN       NaN

# %%
dflang2015['C++'] = dflang2015['C++'].astype(dtype = 'int')
dflang2015['C++'].sum()
# Out:
# 4840

# %%
dflang2015['C++'] = ((dflang2015['C++_ini'].isnull() == 0) | 
                             (dflang2015['C++11'].isnull() == 0))#.astype(dtype = 'int')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'C++_ini'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-235-2190f5cb3689> in <module>
# ----> 1 dflang2015_counts['C++'] = ((dflang2015_counts['C++_ini'].isnull() == 0) |
#       2                              (dflang2015_counts['C++11'].isnull() == 0)).astype(dtype = 'int')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'C++_ini'

# %%
dflang2015.head()
# Out:
#      C C++_ini C++11   C# CoffeeScript Clojure Dart   F#   Go Haskell  Java  \
# 0  NaN     NaN   NaN  NaN          NaN     NaN  NaN  NaN  NaN     NaN  Java
# 1  NaN     NaN   NaN   C#          NaN     NaN  NaN  NaN  NaN     NaN   NaN
# 2  NaN     NaN   NaN   C#          NaN     NaN  NaN  NaN  NaN     NaN   NaN
# 3  NaN     NaN   NaN  NaN          NaN     NaN  NaN  NaN  NaN     NaN   NaN
# 4  NaN     NaN   NaN   C#          NaN     NaN  NaN  NaN   Go     NaN   NaN
#
#    JavaScript Matlab Objective-C Perl  PHP  Python    R Ruby Rust  Scala  SQL  \
# 0         NaN    NaN         NaN  NaN  NaN     NaN  NaN  NaN  NaN  Scala  NaN
# 1         NaN    NaN         NaN  NaN  NaN     NaN  NaN  NaN  NaN    NaN  NaN
# 2         NaN    NaN         NaN  NaN  NaN     NaN  NaN  NaN  NaN    NaN  NaN
# 3  JavaScript    NaN         NaN  NaN  PHP  Python  NaN  NaN  NaN    NaN  SQL
# 4         NaN    NaN         NaN  NaN  NaN     NaN  NaN  NaN  NaN    NaN  NaN
#
#   Swift Visual Basic / VBA    C++
# 0   NaN                NaN  False
# 1   NaN                NaN  False
# 2   NaN                NaN  False
# 3   NaN                NaN  False
# 4   NaN                NaN  False

# %%
print(dflang2015['C++_ini'].count(), 
dflang2015['C++11'].count(),
dflang2015['C++'].sum())
# Out:
# 4529 1851 4840

# %%
#checking that the OR expression worked correctly:
dflang2015.loc[:,('C++_ini', 'C++11', 'C++')].reindex().head(n=50)
# Out:
#    C++_ini  C++11    C++
# 0      NaN    NaN  False
# 1      NaN    NaN  False
# 2      NaN    NaN  False
# 3      NaN    NaN  False
# 4      NaN    NaN  False
# 5      NaN    NaN  False
# 6      NaN    NaN  False
# 7      NaN    NaN  False
# 8      NaN    NaN  False
# 9      NaN    NaN  False
# 10     NaN    NaN  False
# 11     NaN    NaN  False
# 12     NaN    NaN  False
# 13     NaN    NaN  False
# 14     NaN    NaN  False
# 15     C++  C++11   True
# 16     NaN    NaN  False
# 17     NaN    NaN  False
# 18     NaN    NaN  False
# 19     NaN    NaN  False
# 20     NaN    NaN  False
# 21     NaN    NaN  False
# 22     NaN    NaN  False
# 23     NaN    NaN  False
# 24     NaN    NaN  False
# 25     NaN    NaN  False
# 26     NaN    NaN  False
# 27     NaN    NaN  False
# 28     NaN    NaN  False
# 29     NaN    NaN  False
# 30     NaN    NaN  False
# 31     NaN    NaN  False
# 32     NaN    NaN  False
# 33     NaN    NaN  False
# 34     NaN    NaN  False
# 35     C++    NaN   True
# 36     NaN    NaN  False
# 37     NaN    NaN  False
# 38     NaN    NaN  False
# 39     NaN    NaN  False
# 40     NaN    NaN  False
# 41     NaN    NaN  False
# 42     C++    NaN   True
# 43     NaN    NaN  False
# 44     C++    NaN   True
# 45     NaN    NaN  False
# 46     NaN    NaN  False
# 47     NaN    NaN  False
# 48     C++    NaN   True
# 49     NaN    NaN  False

# %%
#take out the now defunct initial C++ column and C++11 column, 
#since they will affect the next fxn
dflang2015 = dflang2015.drop(['C++_ini', 'C++11'], axis = 1)
dflang2015.head()
# Out:
#      C   C# CoffeeScript Clojure Dart   F#   Go Haskell  Java  JavaScript  \
# 0  NaN  NaN          NaN     NaN  NaN  NaN  NaN     NaN  Java         NaN
# 1  NaN   C#          NaN     NaN  NaN  NaN  NaN     NaN   NaN         NaN
# 2  NaN   C#          NaN     NaN  NaN  NaN  NaN     NaN   NaN         NaN
# 3  NaN  NaN          NaN     NaN  NaN  NaN  NaN     NaN   NaN  JavaScript
# 4  NaN   C#          NaN     NaN  NaN  NaN   Go     NaN   NaN         NaN
#
#   Matlab Objective-C Perl  PHP  Python    R Ruby Rust  Scala  SQL Swift  \
# 0    NaN         NaN  NaN  NaN     NaN  NaN  NaN  NaN  Scala  NaN   NaN
# 1    NaN         NaN  NaN  NaN     NaN  NaN  NaN  NaN    NaN  NaN   NaN
# 2    NaN         NaN  NaN  NaN     NaN  NaN  NaN  NaN    NaN  NaN   NaN
# 3    NaN         NaN  NaN  PHP  Python  NaN  NaN  NaN    NaN  SQL   NaN
# 4    NaN         NaN  NaN  NaN     NaN  NaN  NaN  NaN    NaN  NaN   NaN
#
#   Visual Basic / VBA    C++
# 0                NaN  False
# 1                NaN  False
# 2                NaN  False
# 3                NaN  False
# 4                NaN  False

# %%
other_lang_2015 = list(set(dflang2015.columns).difference(set(list_lang_comm)))
other_lang_2015
# Out:
# ['Dart', 'Haskell', 'CoffeeScript', 'Perl', 'Matlab']

# %%
dflang2015['Other(s)'] = ((dflang2015['Dart'].isnull() == 0) | 
                             (dflang2015['Haskell'].isnull() == 0) |
                                (dflang2015['CoffeeScript'].isnull() == 0) |
                                (dflang2015['Perl'].isnull() == 0) |
                                (dflang2015['Matlab'].isnull() == 0))

# %%
dflang2015 = dflang2015.drop(other_lang_2015, axis = 1)

# %%
dflang2015['Other(s)'].sum()
# Out:
# 2591

# %%
dflang2015.shape
# Out:
# (26086, 19)

# %%
dflang2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26086 entries, 0 to 26085
# Data columns (total 19 columns):
# C                     3612 non-null object
# C#                    6949 non-null object
# Clojure               176 non-null object
# F#                    174 non-null object
# Go                    462 non-null object
# Java                  8219 non-null object
# JavaScript            11962 non-null object
# Objective-C           1719 non-null object
# PHP                   6529 non-null object
# Python                5238 non-null object
# R                     755 non-null object
# Ruby                  1765 non-null object
# Rust                  103 non-null object
# Scala                 538 non-null object
# SQL                   9439 non-null object
# Swift                 759 non-null object
# Visual Basic / VBA    1701 non-null object
# C++                   4840 non-null float64
# Other(s)              2591 non-null float64
# dtypes: float64(2), object(17)
# memory usage: 3.8+ MB

# %%
dflang2015_counts = dflang2015_counts.count()
#df2015_mix_count.index = df2015_mix_count.index.str.replace('Current Lang & Tech: ', '')

# %%
dflang2015_counts
# Out:
# C                      3612
# C#                     6949
# Clojure                 176
# F#                      174
# Go                      462
# Java                   8219
# JavaScript            11962
# Objective-C            1719
# PHP                    6529
# Python                 5238
# R                       755
# Ruby                   1765
# Rust                    103
# Scala                   538
# SQL                    9439
# Swift                   759
# Visual Basic / VBA     1701
# C++                    4840
# Other(s)               2591
# dtype: int64

# %%
#converts 1-d series to a 2 column df
def elevate_series(ini_df, series_name, index_name):
    series = ini_df.count()
    series = series.rename_axis(index_name)
    series = series.rename(series_name)
    df = series.reset_index()
    df.sort_values(by=['Languages'], inplace = True)
    return series, df

#replaced this
#df2015_mix_count = df2015_mix_count.rename('Count')
#df2015_mix_count = df2015_mix_count.rename_axis('Lang').reset_index()

# %%
serlang2015_counts, dflang2015_counts = elevate_series(dflang2015_counts, 'Count 2015', 'Languages')

# %%
dfmix2015_counts

# %%
df2017_col_names = df2017.columns
for x in df2017_col_names:
    print(x)

# %%
df2018_col_names = df2018.columns
for x in df2018_col_names:
    print(x)

# %%
print(df2019.shape)
print(df2019.info())

# %%
def eval_complex_col(df, col):
    col_num = df[df[col].isnull() == 0].shape[0]
    col_df = df[col].value_counts().reset_index()
    col_df.rename(columns={'index': col, col:'count'}, inplace = True)
    col_series = pd.Series(col_df[col].unique()).dropna()
    clean_list = col_series.str.split(pat = ';').tolist()
    

    flat_list = []
    for sublist in clean_list:
        for item in sublist:
            flat_list.append(item)
    clean_series = pd.DataFrame(flat_list)
    clean_series[0] = clean_series[0].str.strip()

    col_vals = clean_series[0].unique()
    cat_count = clean_series[0].value_counts()
    
    
    
#    print('Unique Categories: ', col_vals)
    return cat_count, col_vals

# %%
mix16_counts, mix16_vals = eval_complex_col(df2016, 'tech_do')
print(mix16_counts, mix16_vals)

# %%
dfmix2016_counts = elevate_series(mix16_counts, 'Count 2016', 'Languages')

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None
dfmix2016_counts

# %%
lang17_counts, lang17_vals = eval_complex_col(df2017, 'HaveWorkedLanguage')
print(lang17_counts, lang17_vals)

# %%
dflang2017_counts = elevate_series(lang17_counts, 'Count 2017', 'Languages')

# %%
dflang2017_counts

# %%
lang18_counts, lang18_vals = eval_complex_col(df2018, 'LanguageWorkedWith')
print(lang18_counts, lang18_vals)

# %%
dflang2018_counts = elevate_series(lang18_counts, 'Count 2018', 'Languages')
dflang2018_counts

# %%
lang19_counts, lang19_vals = eval_complex_col(df2019, 'LanguageWorkedWith')
print(lang19_counts, lang19_vals)

# %%
lang19_counts.index

# %%
dflang2019_counts = elevate_series(lang19_counts, 'Count 2019', 'Languages')
dflang2019_counts

# %%
dflang2019_counts.Languages

# %%
past5yr_test = pd.concat([dflang2019_counts.Languages, 
                          dflang2018_counts.Languages, 
                          dflang2017_counts.Languages, 
                         dfmix2016_counts.Languages, 
                         dfmix2015_counts.Languages], join = 'outer', keys=['19', '18', '17', '16', '15'], axis = 1, sort = False)
pd.options.display.max_columns = None
pd.options.display.max_rows = None
print(past5yr_test)

# %%
db19_counts, db19_vals = eval_complex_col(df2019, 'DatabaseWorkedWith')
platform19_counts, platform19_vals = eval_complex_col(df2019, 'PlatformWorkedWith')
webframe19_counts, webframe19_vals = eval_complex_col(df2019, 'WebFrameWorkedWith')
misctech19_counts, misctech19_vals = eval_complex_col(df2019, 'MiscTechWorkedWith')

print(db19_vals, platform19_vals, webframe19_vals, misctech19_vals)

# %%
#Provides list of unwanted variables to be used as a reference 
#for cleaning the languages df's
not_lang_list = list(db19_vals) + list(platform19_vals) + list(webframe19_vals) + list(misctech19_vals)
not_lang = pd.Series(not_lang_list).sort_values()
not_lang = not_lang[not_lang != 'Other(s):']
not_lang

# %%
print(dfmix2015_counts.shape[0], dfmix2016_counts.shape[0], dflang2017_counts.shape[0], dflang2018_counts.shape[0], dflang2019_counts.shape[0])

# %%
#dflang2019_counts.merge(dflang2018_counts, how = 'inner')

# %%
set2019 = set(dflang2019_counts.Languages)
set2018 = set(dflang2018_counts.Languages)
set2017 = set(dflang2017_counts.Languages)
set2016 = set(dfmix2016_counts.Languages)
set2015 = set(dfmix2015_counts.Languages)

# %%
#finds common values in the Language columns of each annual dataframe
list_lang_comm = list(set2019.intersection(set2018, set2017, set2016, set2015))
print(len(list_lang_comm), list_lang_comm)

# %%
set_all = set2019.copy()
set_all.update(set2018, set2017, set2016, set2015)
set_all

# %%
set_all_minus_comm = set(set_all).difference(set(list_lang_comm))

# %%
set_other_lang = set_all_minus_comm.difference(set(not_lang))
#looking for duplicates, plus want list of "Other(s)"
set_other_lang

# %%
set1 = set(dflang2019_counts.Languages).symmetric_difference(dflang2018_counts.Languages)

# %%
set2 = set(dflang2019_counts.Languages).symmetric_difference(dflang2017_counts.Languages)

# %%
def merge_diff(df1, df2, df3, df4, df5):
    diff_list = set(df1.Languages).symmetric_difference(df2.Languages)
    diff_list.update(set(df1.Languages).symmetric_difference(df3.Languages))    
    diff_list.update(set(df1.Languages).symmetric_difference(df4.Languages))    
    diff_list.update(set(df1.Languages).symmetric_difference(df5.Languages))    
    return list(diff_list)

# %%
diff_lang_ini = merge_diff(dflang2019_counts, dflang2018_counts, dflang2017_counts, dfmix2016_counts, dfmix2015_counts)

# %%
diff_lang_list = pd.Series(diff_lang_ini).sort_values().unique()
diff_lang_list

# %%
list_dropping = diff_lang_list.copy()

# %%
'''
dflang2019_counts.merge(dflang2018_counts, 
                        how = 'outer', 
                        indicator = True).log[lambda x: x['_merge'] == 'right_only']

# %%
    (cat_count/col_num*100).plot(kind = plot_type, figsize = (7,10))
    plt.xlabel('Proportion (%)')
    plt.ylabel(col)
    plt.grid(True)
    plt.show()

# %%
def compare_plt(column, n, df_low_miss, df_high_miss):
    fig, axs = plt.subplots(n,2, figsize=(10, 5))
    fig.subplots_adjust(hspace =2 , wspace=.2)
    axs = axs.ravel()
    for i in range(n):
        plt.subplot(121)
        sns.countplot(x = column, data = df_low_miss).set_title('Few missing')
        plt.subplot(122)
        sns.countplot(x = column, data = df_high_miss).set_title('High missing')

# %%
compare_plt('SOComm', 5, df2019_lowmiss, df2019_highmiss)

# %%
import warnings
warnings.filterwarnings("ignore")
for col in low_miss_list:
    compare_plt(col, 5, df2019_lowmiss, df2019_highmiss)

# %% [markdown]
# # Questions
# is educational level related to salary?
# What are the biggest factors relating to salary?
# Languages related to salary?
# Type of developer related to salary?
#
# What languages, platforms, etc are people using?
# What languages are people likely to learn together?
#
#
#
# # Variables of interest:
# ConvertedComp - annual compensation
# WorkWeekHrs - hours/week worked
# LanguageWorkedWith
# DatabaseWorkedWith
# PlatformWorkedWith
# WebFrameWorkedWith
# MiscTechWorkedWith
# DevEnviron
# OpSys
#
# LastInt - "In your most recent successful job interview (resulting in a job offer), you were asked to... (check all that apply)"
#
# JobSat
# CareerSat
# YearsCodePro - How many years have you coded professionally (as a part of your work)?
# DevType
# OrgSize
# EduOther
# UndergradMajor
# EdLevel
# Country
# Age
# Gender
# Ethnicity

# %%
for x in schema2019['QuestionText']:
    print(x)

# %% [markdown]
# Randomized respondent ID number (not in order of survey response time)
# Which of the following options best describes you today? Here, by "developer" we mean "someone who writes code."
# Do you code as a hobby?
# How often do you contribute to open source?
# How do you feel about the quality of open source software (OSS)?
#
#
# Which of the following best describes your current employment status?
# In which country do you currently reside?
#
#
# Are you currently enrolled in a formal, degree-granting college or university program?
# Which of the following best describes the highest level of formal education that you’ve completed?
#
#
# What was your main or most important field of study?
# Which of the following types of non-degree education have you used or participated in? Please select all that apply.
# Approximately how many people are employed by the company or organization you work for?
# Which of the following describe you? Please select all that apply.
# Including any education, how many years have you been coding?
#
# At what age did you write your first line of code or program? (E.g., webpage, Hello World, Scratch project)
# How many years have you coded professionally (as a part of your work)?
#
#
# Overall, how satisfied are you with your career thus far?
# How satisfied are you with your current job? (If you work multiple jobs, answer for the one you spend the most hours on.)
#
#
# How confident are you that your manager knows what they’re doing?
# Do you believe that you need to be a manager to make more money?
# Do you want to become a manager yourself in the future?
#
#
# Which of the following best describes your current job-seeking status?
# When was the last time that you took a job with a new employer?
# In your most recent successful job interview (resulting in a job offer), you were asked to... (check all that apply)
# Have you ever been asked to solve FizzBuzz in an interview?
# Imagine that you are deciding between two job offers with the same compensation, benefits, and location. Of the following factors, which 3 are MOST important to you?
# Think back to the last time you updated your resumé, CV, or an online profile on a job site. What is the PRIMARY reason that you did so?
#
#
# Which currency do you use day-to-day? If your answer is complicated, please pick the one you're most comfortable estimating in.
# Which currency do you use day-to-day? If your answer is complicated, please pick the one you're most comfortable estimating in.
#
# What is your current total compensation (salary, bonuses, and perks, before taxes and deductions), in `CurrencySymbol`? Please enter a whole number in the box below, without any punctuation. If you are paid hourly, please estimate an equivalent weekly, monthly, or yearly salary. If you prefer not to answer, please leave the box empty.
# Is that compensation weekly, monthly, or yearly?
#
# Salary converted to annual USD salaries using the exchange rate on 2019-02-01, assuming 12 working months and 50 working weeks.
#
#
# On average, how many hours per week do you work?
# How structured or planned is your work?
#
#
# Of these options, what are your greatest challenges to productivity as a developer? Select up to 3:
# How often do you work remotely?
# Where would you prefer to work?
# For the specific work you do, and the years of experience you have, how do you rate your own level of competence?
# Do you review code as part of your work?
# On average, how many hours per week do you spend on code review?
#
#
#
# Does your company regularly employ unit tests in the development of their products?
# How does your company make decisions about purchasing new technology (cloud, AI, IoT, databases)?
# What level of influence do you, personally, have over new technology purchases at your organization?
#
#
# Which of the following programming, scripting, and markup languages have you done extensive development work in over the past year, and which do you want to work in over the next year?  (If you both worked with the language and want to continue to do so, please check both boxes in that row.)
# Which of the following programming, scripting, and markup languages have you done extensive development work in over the past year, and which do you want to work in over the next year?  (If you both worked with the language and want to continue to do so, please check both boxes in that row.)
# Which of the following database environments have you done extensive development work in over the past year, and which do you want to work in over the next year?   (If you both worked with the database and want to continue to do so, please check both boxes in that row.)
# Which of the following database environments have you done extensive development work in over the past year, and which do you want to work in over the next year?   (If you both worked with the database and want to continue to do so, please check both boxes in that row.)
# Which of the following platforms have you done extensive development work for over the past year?   (If you both developed for the platform and want to continue to do so, please check both boxes in that row.)
# Which of the following platforms have you done extensive development work for over the past year?   (If you both developed for the platform and want to continue to do so, please check both boxes in that row.)
# Which of the following web frameworks have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the framework and want to continue to do so, please check both boxes in that row.)
# Which of the following web frameworks have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the framework and want to continue to do so, please check both boxes in that row.)
# Which of the following other frameworks, libraries, and tools have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the technology and want to continue to do so, please check both boxes in that row.)
# Which of the following other frameworks, libraries, and tools have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the technology and want to continue to do so, please check both boxes in that row.)
# Which development environment(s) do you use regularly?  Please check all that apply.
# What is the primary operating system in which you work?
#
#
# How do you use containers (Docker, Open Container Initiative (OCI), etc.)?
# How is your organization thinking about or implementing blockchain technology?
# Blockchain / cryptocurrency technology is primarily:
#
#
# Do you think people born today will have a better life than their parents?
# Are you the "IT support person" for your family?
#
#
# Have you tried turning it off and on again?
# What social media site do you use the most?
# Do you prefer online chat or IRL conversations?
# What do you call it?
#
#
# To the best of your memory, when did you first visit Stack Overflow?
# How frequently would you say you visit Stack Overflow?
# I visit Stack Overflow to... (check all that apply)
# On average, how many times a week do you find (and use) an answer on Stack Overflow?
# Think back to the last time you solved a coding problem using Stack Overflow, as well as the last time you solved a problem using a different resource. Which was faster?
# About how much time did you save? If you're not sure, please use your best estimate.
#
# Do you have a Stack Overflow account?
# How frequently would you say you participate in Q&A on Stack Overflow? By participate we mean ask, answer, vote for, or comment on questions.
# Have you ever used or visited Stack Overflow Jobs?
# Have you ever used Stack Overflow for Enterprise or Stack Overflow for Teams?
# Do you consider yourself a member of the Stack Overflow community?
# Compared to last year, how welcome do you feel on Stack Overflow?
# Would you like to see any of the following on Stack Overflow? Check all that apply.
#
#
# What is your age (in years)? If you prefer not to answer, you may leave this question blank.
# Which of the following do you currently identify as? Please select all that apply. If you prefer not to answer, you may leave this question blank.
# Do you identify as transgender?
# Which of the following do you currently identify as? Please select all that apply. If you prefer not to answer, you may leave this question blank.
# Which of the following do you identify as? Please check all that apply. If you prefer not to answer, you may leave this question blank.
# Do you have any dependents (e.g., children, elders, or others) that you care for?
